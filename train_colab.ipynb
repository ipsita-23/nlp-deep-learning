# %% [markdown]
# # NL2SQL Intent Classifier Training
# **MiniLM + Linear head fine-tuned on b-mc2/sql-create-context**
#
# Runtime → Change runtime type → T4 GPU → Save

# %%
# Step 1: Install deps
# !pip install -q torch sentence-transformers datasets scikit-learn

# %%
# Step 2: Clone repo
# !git clone https://github.com/S-Axhwin/nlp-to-sql-deep.git
# %cd nlp-to-sql-deep

# %%
# Step 3: Prepare dataset (download + label)
# !python prepare_dataset.py

# %%
# Step 4: Train
# !python train_intent.py

# %%
# Step 5: Download the trained model
from google.colab import files
files.download('models/intent_classifier.pt')
